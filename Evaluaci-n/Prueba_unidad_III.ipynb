# %% [markdown]
# <img src="logo.png" alt="Logo Institución" width="200" style="display: block; margin-right: 100%;">
#
# # Prueba Práctica - Unidad III Estructuras de Control Selectivas
#
# #### **Instrucciones Generales**
# - **Tiempo asignado**: 60-90 minutos
# - **Modalidad**: Individual
# - **Lenguaje**: Python 3.x
# - **Requisitos**: Resolver usando programación estructurada con estructuras de control condicionales

# %% [markdown]
# ##### Para cada ejercicio:
# 1. Lea atentamente la descripción del problema.
# 2. Implemente la solución solicitada.
# 3. Use entradas por consola (input) para obtener los datos.
# 4. Muestre los resultados con formato claro.
# 5. Use nombres de variables descriptivos y comentarios cuando sea necesario.
# 6. No olvides incluir comentarios en tu código para explicar tu razonamiento.

# %% [markdown]
# # 🛤️ Ejercicio 1: Control de Tren (Valor - 6 pts)
#
# ### Descripción
# Simula el sistema de control de un tren que debe responder a señales en la vía.
# Las señales pueden ser **"verde"**, **"amarillo"** o **"rojo"**.
# El tren debe ajustar su velocidad base según la señal actual y la distancia hasta la próxima estación:
#
# - **Señal verde**:
#   - Acelera a **100 km/h** si la distancia es mayor a 5 km.
#   - Mantiene **80 km/h** en caso contrario.
#
# - **Señal amarilla**:
#   - Reduce la velocidad a **50 km/h** si la distancia es mayor a 3 km.
#   - De lo contrario, reduce a **30 km/h**.
#
# - **Señal roja**:
#   - Frena hasta **0 km/h** inmediatamente.
#
# - **Obstáculo en la vía**:
#   - El tren debe frenar a **0 km/h**, independientemente de la señal.
#
# ---
#
# ### ✅ Salida esperada
# El programa debe devolver la velocidad actual del tren en base a las condiciones dadas.
#
# **Ejemplo:**
# - Entrada: `señal="amarillo", distancia=4, obstáculo=False`
# - Salida: `Velocidad: 50 km/h`

# %%
#Pregunte al ususario la distaancia
Distancia= int(input("Ingrese la distancia en kilometros: "))

# Pregunte al usuario si hay un obstaculo
Obstaculo= bool(input("¿Hay un obstáculo en el camino? Si no hay no escriba nada: "))

#Categoriza la respuesta en forma booleana para vver si hay o no obstaculos
if Obstaculo == True:
    ObsStatus = "Hay obstaculos en el camino"
else:
    ObsStatus = "No hay obstaculos en el camino"

# Imprime dist y obstaculo para el usuario
print(f"La distancia es igual a {Distancia} km y {ObsStatus}")

#Verifica el estado del obstaculo y si es True detiene el programa luego de detener el tren
if Obstaculo == True:
    
    print("Detengase ahora mismo.")
    quit()
else:
    print("Puede continuar su camino.")
    

# Pregunta al usuario el estado del semaforo
print("Estado del semaforo: Amarillo [1], Rojo [2], Verde [3]")
SmfrClr = int(input("Ingrese el estado del semaforo: "))

# Calcula la velocidad segun el estado del semaforo y la distancia
if SmfrClr == 1:
    print("El semáforo está en amarillo.")
    if Distancia > 3:
        print("Reduzca la velocidad a 50 km/h.")
    else:
        print("Reduzca la velocidad a 30 km/h.")
        
elif SmfrClr == 2:
    print("El semáforo está en rojo.")
    print("Reduzca a 0 km/h inmediatamente.")
elif SmfrClr == 3:
    print("El semáforo está en verde.")
    if Distancia > 5:
        print("Acelere a 100 km/h.")
    else:
        print("Mantenga la velocidad a 80km/h")
else:
    print("Estado de semáforo no válido.")
    
# Fin del programa
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/RAFA/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # ☢️ Ejercicio 2: Mitigación de Fusión Nuclear (Valor - 7 pts)
#
# ### Descripción
# Eres responsable de monitorear un **reactor nuclear**.
# Debes determinar el estado del reactor en base a la **temperatura**, la **presión** y el **nivel de refrigerante**.
#
# Las reglas son:
#
# - Si la **temperatura > 800 °C** y la **presión > 500 bar**, el estado es **"CRÍTICO"**.
# - Si la **temperatura está entre 600 °C y 800 °C** o la **presión entre 300 bar y 500 bar**, el estado es **"ALERTA"**.
# - Si el **nivel de refrigerante < 50%**, el estado se degrada un nivel (ejemplo: de "NORMAL" a "ALERTA").
# - En cualquier otro caso, el estado es **"NORMAL"**.
#
# ---
#
# ### ✅ Salida esperada
# El programa debe imprimir el estado del reactor.
#
# **Ejemplo:**
# - Entrada: `temperatura=750, presión=400, refrigerante=45`
# - Salida: `Estado: ALERTA`
#   *(porque el refrigerante baja el estado, pero ya estaba en alerta por temperatura y presión)*

# %%
print("Bienvenido")

Temperatura = int(input("Ingrese la temperatura en grados Celsius: "))
if Temperatura >= 801:
    TemperaturaStatus = 1
if Temperatura >= 600 and Temperatura <= 800:
    TemperaturaStatus = 0

Presion = int(input("Ingrese la presión en bar: "))
if Presion >= 500:
    PresionStatus = 1
if Presion >= 300 and Presion <= 499:
    PresionStatus = 0
    
Refrigerante = int(input("Ingrese el nivel de refrigerante en %: "))
if Refrigerante <= 50:
    RefrigeranteStatus = -1
elif Refrigerante >= 51:
    RefrigeranteStatus = 0
    
if Presion >= 500 and Temperatura >= 801 and Refrigerante <= 50:
    print("Critico")
elif Presion >= 300 and Presion <= 499 and Temperatura >= 600 and Temperatura <= 800 and Refrigerante >= 51:
    print("Alerta")
elif Presion >= 300 and Presion <= 499 and Temperatura >= 600 and Temperatura <= 800 and Refrigerante <= 50:
    print("Critico")
else:
    print(" Estado normal")
    print("Estado Normal")
print("Adios")

# %% [markdown]
# # 💰 Ejercicio 3: Cálculo de Impuestos (Valor - 7 pts)
#
# ### Descripción
# Calcula el **impuesto sobre la renta** en base al **ingreso anual**, la **edad** y el **número de dependientes**.
#
# Las reglas son:
#
# - Ingresos **≤ $10,000**: no pagan impuestos.
# - Ingresos **entre $10,001 y $50,000**: pagan **10% sobre el exceso** de $10,000.
# - Ingresos **> $50,000**: pagan **20% sobre el exceso de $50,000** más **$4,000**.
# - Mayores de **65 años**: reducción del **5% en el impuesto total**.
# - Por cada **dependiente**, se reduce **$1,000 del ingreso gravable** antes de calcular el impuesto.
#
# ---
#
# ### ✅ Salida esperada
# El programa debe calcular y mostrar el impuesto a pagar.
#
# **Ejemplo:**
# - Entrada: `ingreso=60000, edad=70, dependientes=2`
# - Salida: `Impuesto: 5320`
#
# 📌 *Explicación:*
# - Ingreso gravable = 60000 - (1000 × 2) = **58000**
# - Impuesto base = 4000 + 20% de (58000 - 50000) = **5600**
# - Descuento por edad = 5% de 5600 = **280**
# - Impuesto final = 5600 - 280 = **5320**

# %%
 
ingreso = int(input("¿Cuál es tu ingreso anual? "))
edad = int(input("¿Cuántos años tienes? "))
dependientes = int(input("¿Cuántos dependientes tienes? "))


 
descuento_dependientes = dependientes * 1000
ingreso_gravable = ingreso - descuento_dependientes

 
if ingreso_gravable < 0:
    ingreso_gravable = 0

print(f"\nIngreso Gravable (después de dependientes): ${ingreso_gravable}")


impuesto_base = 0


if ingreso_gravable <= 10000:
    impuesto_base = 0 
    print("El ingreso gravable es menor o igual a $10,000. Impuesto base: $0")


elif ingreso_gravable <= 50000:
    #
    exceso = ingreso_gravable - 10000
    impuesto_base = exceso * 0.10 
    print(f"El ingreso gravable está entre $10,001 y $50,000.")
    print(f"Exceso sobre $10,000: ${exceso}. Impuesto base (10%): ${impuesto_base}")


else:
    
    impuesto_fijo = 4000
    exceso = ingreso_gravable - 50000
    impuesto_exceso = exceso * 0.20   
    impuesto_base = impuesto_fijo + impuesto_exceso
    print(f"El ingreso gravable es mayor a $50,000.")
    print(f"Impuesto fijo: ${impuesto_fijo}. Exceso sobre $50,000: ${exceso}.")
    print(f"Impuesto sobre exceso (20%): ${impuesto_exceso}. Impuesto base total: ${impuesto_base}")

 
impuesto_final = impuesto_base
descuento_edad = 0

if edad > 65:
    
    descuento_edad = impuesto_base * 0.05   
    impuesto_final = impuesto_base - descuento_edad
    print(f"\n¡Felicidades! Tienes más de 65 años.")
    print(f"Descuento por edad (5% de ${impuesto_base}): ${descuento_edad}")

 
impuesto_a_pagar = round(impuesto_final)

print("\n" + ("-" * 30))
print(f"✅ **Impuesto final a pagar: ${impuesto_a_pagar}**")
print("-" * 30)

# %% [markdown]
# ### **¡Éxito en la evaluación!**
